# %%
def greet(name):
    return 'Hello ' + name

print(greet('World'))
# Out:
# Hello World

# %%
def dms_to_decimal(degrees, minutes, seconds):
    if degrees < 0:
        result = degrees - minutes/60 - seconds/3600
    else:
        result = degrees + minutes/60 + seconds/3600
    return result

# %%
output = dms_to_decimal(85, 25, 45)
print(output)
# Out:
# 85.42916666666667

# %% [markdown]
# Exercise

# %%
def dms_to_decimal(degrees, minutes, seconds):
    if degrees < 0:
        result = degrees - minutes/60 - seconds/3600
    else:
        result = degrees + minutes/60 + seconds/3600
    return result

coordinate = '''37° 46' 26.2992"'''

# Add the code below to extract the parts from the coordinate string,
# call the function to convert to decimal degrees and print the result
# The expected answer is 37.773972

# %%
def dms_to_decimal(degrees, minutes, seconds):
    if degrees < 0:
        result = degrees - minutes/60 - seconds/3600
    else:
        result = degrees + minutes/60 + seconds/3600
    return result

# %%
output = dms_to_decimal(37, 46, 26.2992)
print(output)
# Out:
# 37.773972

# %%
# Hint: Converting strings to numbers
# When you extract the parts from the coordinate string, they are strings
# You will need to use the built-in int() / float() functions to
# convert them to numbers
x = '25'
print(x, type(x))
y = int(x)
print(y, type(y))
# Out:
# 25 <class 'str'>
# 25 <class 'int'>

# %%
coord = "23.5,87.2"

x_str, y_str = coord.split(",")

x = float(x_str)
y = float(y_str)

print(x, type(x))
print(y, type(y))
# Out:
# 23.5 <class 'float'>
# 87.2 <class 'float'>
